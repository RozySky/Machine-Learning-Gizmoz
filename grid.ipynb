# %%
![title]()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
dataset = pd.read_csv('data/2d.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       509 non-null    int64
#  1   alpha   509 non-null    int64
#  2   beta    509 non-null    int64
# dtypes: int64(3)
# memory usage: 12.1 KB

# %%
dataset.isnull().sum()
# Out:
# y        0
# alpha    0
# beta     0
# dtype: int64

# %%
dataset.head()
# Out:
#    y  alpha  beta
# 0  1     94   212
# 1  0    875   700
# 2  0    877   766
# 3  0    811   941
# 4  1     97   178

# %%
dataset.plot(kind='scatter', x='alpha', y='beta')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_data = dataset.drop('y', 1)
y_data = dataset['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
lg = LogisticRegression()
lg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lg.score(x_train, y_train)
# Out:
# 1.0

# %%
lg.score(x_test, y_test)
# Out:
# 1.0

# %%
prd = lg.predict(x_test)

# %%
sns.heatmap(confusion_matrix(prd, y_test), annot = True, fmt= 'd')

# %%
dataset_2 = pd.read_csv('data/2d_2.csv')
dataset_2.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_2.drop('y', 1)
y_data = dataset_2['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_train, y_train) * 100
# Out:
# 100.0

# %%
KN.score(x_test, y_test)
# Out:
# 1.0

# %%
pri = KN.predict(x_test)

# %%
accuracy_score(y_test, pri)
# Out:
# 1.0

# %%
dataset_3 = pd.read_csv('data/2d_3.csv')
dataset_3.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_3.drop('y', 1)
y_data = dataset_3['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 100.0

# %%
dataset_4 = pd.read_csv('data/2d_4.csv')
dataset_4.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_4.drop('y', 1)
y_data = dataset_4['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 100.0

# %%
dataset_5 = pd.read_csv('data/2d_5.csv')
dataset_5.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_5.drop('y', 1)
y_data = dataset_5['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 98.1283422459893

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier().fit(x_train, y_train) # Gini
forest_ent = RandomForestClassifier(criterion='entropy').fit(x_train, y_train)

# %%
forest.score(x_test, y_test)
# Out:
# 0.9906417112299465

# %%
forest_ent.score(x_test, y_test)
# Out:
# 0.9906417112299465

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier().fit(x_train, y_train)
tree.score(x_test, y_test)
# Out:
# 0.9812834224598931

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB = GaussianNB().fit(x_train, y_train)

# %%
NB.score(x_test, y_test)
# Out:
# 0.910427807486631

# %%
LG = LogisticRegression()
LG.fit(x_train, y_train)
LG.score(x_test, y_test)
# Out:
# 0.910427807486631

# %%
 # Random Forest With gini Criterion preforms well

# %%
dataset_6 = pd.read_csv('data/2d_6.csv')
dataset_6.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_6.drop('y', 1)
y_data = dataset_6['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 88.2

# %%
forest = RandomForestClassifier().fit(x_train, y_train) # Gini
forest_ent = RandomForestClassifier(criterion='entropy').fit(x_train, y_train)

# %%
forest.score(x_test, y_test)
# Out:
# 0.876

# %%
forest_ent.score(x_test, y_test)
# Out:
# 0.87

# %%
tree = DecisionTreeClassifier().fit(x_train, y_train)
tree.score(x_test, y_test)
# Out:
# 0.87

# %%
NB = GaussianNB().fit(x_train, y_train)

# %%
NB.score(x_test, y_test)
# Out:
# 0.874

# %%
LG = LogisticRegression()

# %%
LG.fit(x_train, y_train)
LG.score(x_test, y_test)
# Out:
# 0.874

# %%
dataset_7 = pd.read_csv('data/2d_7.csv')
dataset_7.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_7.drop('y', 1)
y_data = dataset_7['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 91.85580774365822

# %%
forest = RandomForestClassifier().fit(x_train, y_train) # Gini
forest_ent = RandomForestClassifier(criterion='entropy').fit(x_train, y_train)

# %%
forest.score(x_test, y_test)
# Out:
# 0.931909212283044

# %%
forest_ent.score(x_test, y_test)
# Out:
# 0.9252336448598131

# %%
tree = DecisionTreeClassifier().fit(x_train, y_train)
tree.score(x_test, y_test)
# Out:
# 0.9172229639519359

# %%
NB = GaussianNB().fit(x_train, y_train)

# %%
NB.score(x_test, y_test)
# Out:
# 0.6542056074766355

# %%
LG = LogisticRegression()

# %%
LG.fit(x_train, y_train)
LG.score(x_test, y_test)
# Out:
# 0.6542056074766355

# %%
dataset_8 = pd.read_csv('data/2d_8.csv')
dataset_8.plot(kind='scatter', x = 'alpha', y='beta')

# %%
x_data = dataset_8.drop('y', 1)
y_data = dataset_8['y']
x_train,x_test,y_train,y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
KN.score(x_test, y_test) * 100
# Out:
# 94.55275229357798

# %%
forest = RandomForestClassifier().fit(x_train, y_train) # Gini
forest_ent = RandomForestClassifier(criterion='entropy').fit(x_train, y_train)

# %%
forest.score(x_test, y_test)
# Out:
# 0.9489678899082569

# %%
forest_ent.score(x_test, y_test)
# Out:
# 0.9472477064220184

# %%
tree = DecisionTreeClassifier().fit(x_train, y_train)
tree.score(x_test, y_test)
# Out:
# 0.9455275229357798

# %%
NB = GaussianNB().fit(x_train, y_train)

# %%
NB.score(x_test, y_test)
# Out:
# 0.856651376146789

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
 {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
 {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
 ]

# %%
forr = RandomForestClassifier()

# %%
grid_search = GridSearchCV(forr, param_grid, cv=5,scoring='accuracy',return_train_score=True)

# %%
grid_search.fit(x_train, y_train)
# Out:
# C:\Users\habab\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\habab\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\habab\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# ...

# %%
import sklearn

# %%
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
grid_search.best_params_
# Out:
# {'max_features': 2, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=2,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=30,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model = grid_search.best_estimator_.score(x_test, y_test)

# %%
print(model * 100, ' % Accuaracy ') # I have not tuned previous models just because its pretty easy but thats how you do it.
# Out:
# 95.06880733944955  % Accuaracy
